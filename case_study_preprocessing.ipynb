# %% [markdown]
# <a href="https://colab.research.google.com/github/amalasoy/Assignment/blob/main/case_study_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/House_Pricing.csv')

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                 NaN  ...             7
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
data.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
data.shape
# Out:
# (21613, 21)

# %%
data.dtypes
# Out:
# ID                                             int64
# Date House was Sold                           object
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                           object
# Condition of the House                        object
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                      float64
# Latitude                                     float64
# ...

# %%
data['ID'].nunique()
# Out:
# 21436

# %%
data.isna().sum()
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       4
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              9
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# ...

# %%
df=data

# %%
df['No of Times Visited'].hist()
# Out:
# <Axes: >

# %%
df['No of Times Visited'].unique() # To check unique values
# Out:
# array([nan, 'Thrice', 'Four', 'Twice', 'Once'], dtype=object)

# %%
df['No of Times Visited'].replace({'Thrice':3,'Four':4, 'Twice':2,'Once' :1}, inplace = True) # replacing string with numbers
# Out:
# /tmp/ipykernel_444/1388899621.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['No of Times Visited'].replace({'Thrice':3,'Four':4, 'Twice':2,'Once' :1}, inplace = True) # replacing string with numbers
# ...

# %%
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View  No of Times Visited  ... Overall Grade  \
# 0              No                  NaN  ...             7
# ...

# %%
df['No of Times Visited'] = df['No of Times Visited'].fillna(df['No of Times Visited'].mean())

# %%
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View  No of Times Visited  ... Overall Grade  \
# 0              No             2.384181  ...             7
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df['No of Times Visited'] = df['No of Times Visited'].fillna(df['No of Times Visited'].mean())

# %%
fig,axs = plt.subplots(5, figsize=(6,12))
plt1 = df['Sale Price'].hist()
plt2 = df['No of Bathrooms'].hist()
plt3 = df['Flat Area (in Sqft)'].hist()
plt4 = df['Lot Area (in Sqft)'].hist()
plt5 = df['Area of the House from Basement (in Sqft)'].hist()
plt.tight_layout()

# %%
df['Area of the House from Basement (in Sqft)'].fillna(df['Area of the House from Basement (in Sqft)'].mean())
# Out:
# 0        1180.0
# 1        2170.0
# 2         770.0
# 3        1050.0
# 4        1680.0
#           ...
# 21608    1530.0
# 21609    2310.0
# 21610    1020.0
# 21611    1600.0
# 21612    1020.0
# Name: Area of the House from Basement (in Sqft), Length: 21613, dtype: float64

# %%
df['Sale Price']=df['Sale Price'].fillna(df['Sale Price'].mean())

# %%
df['No of Bathrooms']=df['No of Bathrooms'].fillna(df['No of Bathrooms'].mean())

# %%
df['Flat Area (in Sqft)']=df['Flat Area (in Sqft)'].fillna(df['Flat Area (in Sqft)'].mean())

# %%
df['Lot Area (in Sqft)']=df['Lot Area (in Sqft)'].fillna(df['Lot Area (in Sqft)'].mean())

# %%
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View  No of Times Visited  ... Overall Grade  \
# 0              No             2.384181  ...             7
# ...

# %%
df.dropna(subset=['Latitude','Zipcode','Longitude','Living Area after Renovation (in Sqft)'], inplace=True)

# %%
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View  No of Times Visited  ... Overall Grade  \
# 0              No             2.384181  ...             7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  float64
# ...

# %%
df.drop(['ID','Zipcode','Latitude','Longitude','Date House was Sold'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Sale Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors Waterfront View  No of Times Visited  \
# 0              5650.0           1.0              No             2.384181
# 1              7242.0           2.0              No             2.384181
# 2             10000.0           1.0              No             2.384181
# 3              5000.0           1.0              No             2.384181
# 4              8080.0           1.0              No             2.384181
#
#   Condition of the House  Overall Grade  \
# 0                   Fair              7
# ...

# %%
df['Condition of the House'].unique()
# Out:
# array(['Fair', 'Excellent', 'Good', 'Bad', 'Okay'], dtype=object)

# %%
df['Condition of the House'].replace({'Fair':3,'Excellent':5, 'Good':4,'Okay' :2, 'Bad':1}, inplace = True)
# Out:
# /tmp/ipykernel_444/4132483790.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Condition of the House'].replace({'Fair':3,'Excellent':5, 'Good':4,'Okay' :2, 'Bad':1}, inplace = True)
# /tmp/ipykernel_444/4132483790.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df.head()
# Out:
#    Sale Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors Waterfront View  No of Times Visited  \
# 0              5650.0           1.0              No             2.384181
# 1              7242.0           2.0              No             2.384181
# 2             10000.0           1.0              No             2.384181
# 3              5000.0           1.0              No             2.384181
# 4              8080.0           1.0              No             2.384181
#
#    Condition of the House  Overall Grade  \
# 0                       3              7
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Waterfront View'] = le.fit_transform(df['Waterfront View'])

# %%
df.head()
# Out:
#    Sale Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  Waterfront View  No of Times Visited  \
# 0              5650.0           1.0                0             2.384181
# 1              7242.0           2.0                0             2.384181
# 2             10000.0           1.0                0             2.384181
# 3              5000.0           1.0                0             2.384181
# 4              8080.0           1.0                0             2.384181
#
#    Condition of the House  Overall Grade  \
# 0                       3              7
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

columns_to_change = ['Sale Price','Flat Area (in Sqft)','Lot Area (in Sqft)','Area of the House from Basement (in Sqft)','Basement Area (in Sqft)','Age of House (in Years)','Renovated Year','Living Area after Renovation (in Sqft)','Lot Area after Renovation (in Sqft)','Overall Grade','Condition of the House','No of Bedrooms','No of Bathrooms']

# %%
df[columns_to_change] = scaler.fit_transform(df[columns_to_change])

# %%
df.head(7)
# Out:
#    Sale Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0   -0.866424       -0.398801        -1.447570            -0.980050
# 1   -0.006002       -0.398801         0.175676             0.533582
# 2   -0.980475       -1.473997        -1.447570            -1.426517
# 3    0.173650        0.676395         1.149623            -0.130674
# 4   -0.082218       -0.398801        -0.148973            -0.435578
# 5    1.877617        0.676395         3.097518             3.637074
# 6   -0.769521       -0.398801         0.175676            -0.397465
#
#    Lot Area (in Sqft)  No of Floors  Waterfront View  No of Times Visited  \
# 0           -0.228368           1.0                0             2.384181
# 1           -0.189935           2.0                0             2.384181
# 2           -0.123353           1.0                0             2.384181
# 3           -0.244060           1.0                0             2.384181
# ...

# %%
df.columns
# Out:
# Index(['Sale Price', 'No of Bedrooms', 'No of Bathrooms',
#        'Flat Area (in Sqft)', 'Lot Area (in Sqft)', 'No of Floors',
#        'Waterfront View', 'No of Times Visited', 'Condition of the House',
#        'Overall Grade', 'Area of the House from Basement (in Sqft)',
#        'Basement Area (in Sqft)', 'Age of House (in Years)', 'Renovated Year',
#        'Living Area after Renovation (in Sqft)',
#        'Lot Area after Renovation (in Sqft)'],
#       dtype='object')

# %%
df.boxplot('Age of House (in Years)')
# Out:
# <Axes: >

# %%
df.boxplot('Sale Price')
# Out:
# <Axes: >

# %%
df.boxplot('Flat Area (in Sqft)')
# Out:
# <Axes: >

# %%
df.boxplot('Renovated Year')
# Out:
# <Axes: >

# %%
df.boxplot('Basement Area (in Sqft)')
# Out:
# <Axes: >

# %%
def iqr_cap(series, factor=1.5):
  q1 = series.quantile(0.25)
  q3 = series.quantile(0.75)
  iqr = q3-q1
  lower = q1-factor*iqr
  upper = q3+factor*iqr

  capped= series.clip(lower,upper)
  return capped

# %%
df['Age of House (in Years)_capped'] = iqr_cap(df['Age of House (in Years)'])

# %%
df['Sale Price_capped'] = iqr_cap(df['Sale Price'])
df['Basement Area (in Sqft)_capped'] = iqr_cap(df['Basement Area (in Sqft)'])
df['Renovated Year_capped'] = iqr_cap(df['Renovated Year'])
df['Flat Area (in Sqft)_capped'] = iqr_cap(df['Flat Area (in Sqft)'])

# %%
df.boxplot('Renovated Year_capped')
# Out:
# <Axes: >

# %%
x = df.drop('Sale Price', axis = 1)
y = df['Sale Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
x_train
# Out:
#        No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 7097         0.676395         1.798921             0.751371
# 18540       -1.473997        -0.148973            -0.588030
# 20025        0.676395         1.798921             1.981878
# 6256         1.751591         0.500325            -0.043558
# 15385       -0.398801        -0.798272            -0.805819
# ...               ...              ...                  ...
# 11968        0.676395         0.500325            -0.054447
# 21579       -0.398801         1.474272            -0.381131
# 5394        -1.473997         0.175676            -0.185121
# 864          0.676395         0.500325            -0.032669
# 15799        0.676395        -0.473623            -0.304905
#
#        Lot Area (in Sqft)  No of Floors  Waterfront View  No of Times Visited  \
# 7097            -0.111161           2.0                0             2.384181
# 18540            0.949741           2.0                0             2.384181
# ...

# %%
x_test
# Out:
#        No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 4986         1.751591         1.474272             1.034497
# 10258       -0.398801        -1.447570            -0.620699
# 4048        -0.398801        -0.798272            -0.555362
# 21271       -0.398801         1.474272            -0.686035
# 10498       -0.398801         1.798921             1.208728
# ...               ...              ...                  ...
# 8945        -1.473997        -1.447570            -1.252286
# 11303        0.676395         0.500325             1.622527
# 20767        0.676395         2.448220             2.482793
# 2526        -0.398801         0.824974             0.239567
# 5005         0.676395         1.149623             1.241396
#
#        Lot Area (in Sqft)  No of Floors  Waterfront View  No of Times Visited  \
# 4986             0.128830           2.0                0             2.000000
# 10258           -0.217915           1.0                0             2.384181
# ...

# %%
y_train
# Out:
# 7097    -0.694666
# 18540   -0.177487
# 20025    1.360438
# 6256    -0.163877
# 15385   -0.245537
#            ...
# 11968    0.791542
# 21579    0.285251
# 5394    -0.351695
# 864     -0.708276
# 15799   -0.422467
# Name: Sale Price, Length: 17287, dtype: float64

# %%
y_test
# Out:
# 4986     0.679940
# 10258   -0.340807
# 4048    -0.852367
# 21271   -0.599396
# 10498    0.652720
#            ...
# 8945    -0.841790
# 11303    0.334247
# 20767    4.790148
# 2526    -0.014168
# 5005    -0.299977
# Name: Sale Price, Length: 4322, dtype: float64
