# %% [markdown]
# <a href="https://colab.research.google.com/github/amalasoy/Assignment/blob/main/Case_study2_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import pandas as pd
data = pd.read_csv('auto-mpg.csv')
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# ####1.Basic Exploration

# %%
data.head(11)
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   18.0          8         307.0        130    3504          12.0
# 1   15.0          8         350.0        165    3693          11.5
# 2   18.0          8         318.0        150    3436          11.0
# 3   16.0          8         304.0        150    3433          12.0
# 4   17.0          8         302.0        140    3449          10.5
# 5   15.0          8         429.0        198    4341          10.0
# 6   14.0          8         454.0        220    4354           9.0
# 7   14.0          8         440.0        215    4312           8.5
# 8   14.0          8         455.0        225    4425          10.0
# 9   15.0          8         390.0        190    3850           8.5
# 10  15.0          8         383.0        170    3563          10.0
#
#     model year  origin                   car name
# 0           70       1  chevrolet chevelle malibu
# 1           70       1          buick skylark 320
# ...

# %%
data.shape
# Total no. of rows = 398 and columns = 9
# Out:
# (398, 9)

# %%
data.describe()
# summary statistics includes - mean, median, standard deviation, minimum and maximum values
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# ####2.Filtering and indexing

# %%
# cars manufactured in 1975 with a weight less than 3000
boolean_expr = ((data['model year']==75) & (data['weight']<3000))
data[boolean_expr]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 167  29.0          4          97.0         75    2171          16.0
# 168  23.0          4         140.0         83    2639          17.0
# 169  20.0          6         232.0        100    2914          16.0
# 170  23.0          4         140.0         78    2592          18.5
# 171  24.0          4         134.0         96    2702          13.5
# 172  25.0          4          90.0         71    2223          16.5
# 173  24.0          4         119.0         97    2545          17.0
# 174  18.0          6         171.0         97    2984          14.5
# 175  29.0          4          90.0         70    1937          14.0
# 177  23.0          4         115.0         95    2694          15.0
# 178  23.0          4         120.0         88    2957          17.0
# 179  22.0          4         121.0         98    2945          14.5
# 180  25.0          4         121.0        115    2671          13.5
# ...

# %%
tiny_data = data[['mpg','car name','weight']]
tiny_data
# Out:
#       mpg                   car name  weight
# 0    18.0  chevrolet chevelle malibu    3504
# 1    15.0          buick skylark 320    3693
# 2    18.0         plymouth satellite    3436
# 3    16.0              amc rebel sst    3433
# 4    17.0                ford torino    3449
# ..    ...                        ...     ...
# 393  27.0            ford mustang gl    2790
# 394  44.0                  vw pickup    2130
# 395  32.0              dodge rampage    2295
# 396  28.0                ford ranger    2625
# 397  31.0                 chevy s-10    2720
#
# [398 rows x 3 columns]

# %%
tiny_data.to_csv('tiny_data.csv')

# %% [markdown]
# ####3.Missing data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
data.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
data_horse = data['horsepower'].unique()
data_horse # missing numeric is there
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %% [markdown]
# ####4.New column

# %%
power_to_weight_ratio = data['horsepower']* 1/data['weight']
data['power to weight ratio'] = power_to_weight_ratio
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin                   car name  power to weight ratio
# ...

# %% [markdown]
# ####5.Group by

# %%
# Mean
g_by = data.groupby('origin')
g_by.mean('mpg')
# Out:
#               mpg  cylinders  displacement  horsepower       weight  \
# origin
# 1       20.083534   6.248996    245.901606  118.814769  3361.931727
# 2       27.891429   4.157143    109.142857   81.241983  2423.300000
# 3       30.450633   4.101266    102.708861   79.835443  2221.227848
#
#         acceleration  model year  power to weight ratio
# origin
# 1          15.033735   75.610442               0.035040
# 2          16.787143   75.814286               0.033841
# 3          16.172152   77.443038               0.035705

# %%
data['origin'].unique()
# Out:
# array([1, 3, 2])

# %% [markdown]
# ####6 & 7 Sorting and application

# %%
s_data = data.sort_values(by='mpg', ascending=False)
s_data.head(10)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0   65.000000    2110          17.9
# 329  44.6          4          91.0   67.000000    1850          13.8
# 325  44.3          4          90.0   48.000000    2085          21.7
# 394  44.0          4          97.0   52.000000    2130          24.6
# 326  43.4          4          90.0   48.000000    2335          23.7
# 244  43.1          4          90.0   48.000000    1985          21.5
# 309  41.5          4          98.0   76.000000    2144          14.7
# 330  40.9          4          85.0  104.469388    1835          17.3
# 324  40.8          4          85.0   65.000000    2110          19.2
# 247  39.4          4          85.0   70.000000    2070          18.6
#
#      model year  origin                         car name  \
# 322          80       3                        mazda glc
# 329          80       3              honda civic 1500 gl
# ...

# %%
def performance_score(row):
    row['mpg'] * row['acceleration'] / row['weight']
    return
    row['mpg'] * row['acceleration'] / row['weight']

performance_score(data)
data['performance score'] = performance_score(data)
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model year  origin                   car name  power to weight ratio  \
# 0          70       1  chevrolet chevelle malibu               0.037100
# 1          70       1          buick skylark 320               0.044679
# 2          70       1         plymouth satellite               0.043655
# 3          70       1              amc rebel sst               0.043694
# 4          70       1                ford torino               0.040591
#
#   performance score
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None

# %%
performance_score = data['mpg']*data['acceleration']* 1 / data['weight']
data['performance score'] = performance_score
data['performance score']
# Out:
# 0      0.061644
# 1      0.046710
# 2      0.057625
# 3      0.055928
# 4      0.051754
#          ...
# 393    0.150968
# 394    0.508169
# 395    0.161743
# 396    0.198400
# 397    0.221103
# Name: performance score, Length: 398, dtype: float64

# %%
data[['mpg','weight','horsepower']].value_counts()
# Out:
# mpg   weight  horsepower
# 29.0  1937    70.0          2
# 33.0  1795    53.0          2
# 27.0  2130    88.0          2
#       2640    88.0          1
#       2202    83.0          1
#                            ..
# 18.5  3525    98.0          1
# 18.2  3830    135.0         1
# 18.1  3410    120.0         1
#       3205    139.0         1
# 19.0  2930    108.0         1
# Name: count, Length: 395, dtype: int64

# %% [markdown]
# 8.Visualization

# %%
mean_mpg = data['mpg'].mean()
mean_weight = data['weight'].mean()
mean_horsepower = data['horsepower'].mean()
for idx, row in data.iloc[::].iterrows():
      print(idx,row['model year'], mean_mpg, mean_weight, mean_horsepower)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1822533313.py in <cell line: 0>()
# ----> 1 mean_mpg = data['mpg'].mean()
#       2 mean_weight = data['weight'].mean()
#       3 mean_horsepower = data['horsepower'].mean()
#       4 for idx, row in data.iloc[::].iterrows():
#       5       print(idx,row['model year'], mean_mpg, mean_weight, mean_horsepower)
#
# NameError: name 'data' is not defined

# %%
mpg = data[data['mpg']>30]
high_mpg_cars = mpg[['cylinders','horsepower','weight']]


high_mpg_cars
# Out:
#      cylinders horsepower  weight
# 397          4         82    2720
# 395          4         84    2295
# 394          4         52    2130
# 391          4         84    2370
# 370          4         85    2575
# ..         ...        ...     ...
# 131          4         65    1836
# 145          4         61    2003
# 144          4         52    1649
# 53           4         65    1773
# 54           4         69    1613
#
# [85 rows x 3 columns]

# %%
high_mpg_cars.to_csv(' high_mpg_cars.csv')

# %%
import pandas as pd
data = pd.read_csv('auto-mpg.csv')
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# 10.Finding Anomalies

# %%
data_mpg = data['mpg']
data_mpg
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
data_mpg.values
# Out:
# array([18. , 15. , 18. , 16. , 17. , 15. , 14. , 14. , 14. , 15. , 15. ,
#        14. , 15. , 14. , 24. , 22. , 18. , 21. , 27. , 26. , 25. , 24. ,
#        25. , 26. , 21. , 10. , 10. , 11. ,  9. , 27. , 28. , 25. , 25. ,
#        19. , 16. , 17. , 19. , 18. , 14. , 14. , 14. , 14. , 12. , 13. ,
#        13. , 18. , 22. , 19. , 18. , 23. , 28. , 30. , 30. , 31. , 35. ,
#        27. , 26. , 24. , 25. , 23. , 20. , 21. , 13. , 14. , 15. , 14. ,
#        17. , 11. , 13. , 12. , 13. , 19. , 15. , 13. , 13. , 14. , 18. ,
#        22. , 21. , 26. , 22. , 28. , 23. , 28. , 27. , 13. , 14. , 13. ,
#        14. , 15. , 12. , 13. , 13. , 14. , 13. , 12. , 13. , 18. , 16. ,
#        18. , 18. , 23. , 26. , 11. , 12. , 13. , 12. , 18. , 20. , 21. ,
#        22. , 18. , 19. , 21. , 26. , 15. , 16. , 29. , 24. , 20. , 19. ,
#        15. , 24. , 20. , 11. , 20. , 21. , 19. , 15. , 31. , 26. , 32. ,
#        25. , 16. , 16. , 18. , 16. , 13. , 14. , 14. , 14. , 29. , 26. ,
# ...

# %%
# to get potential outliers
# here one outlier is there - (46.25)
import matplotlib.pyplot as plt
plt.boxplot(data_mpg)
plt.show()

# %%
plt.hist(data_mpg)
plt.show()

# %%
import numpy as np
Q1 = np.percentile(data_mpg,25)
Q2 = np.percentile(data_mpg,50)
Q3= np.percentile(data_mpg,75)
Q1,Q2,Q3
# Out:
# (np.float64(17.5), np.float64(23.0), np.float64(29.0))

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# 11.5

# %%
out_1 = Q1 - 1.5 * IQR
out_1
# Out:
# np.float64(0.25)

# %%
out_2 = Q3 + 1.5 * IQR
out_2
# Out:
# np.float64(46.25)

# %%
#outlier
outlier= data[data['mpg']>=46]
outlier
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 322  46.6          4          86.0         65    2110          17.9
#
#      model year  origin   car name
# 322          80       3  mazda glc

# %%
df = outlier[['mpg','car name','model year']]
df
# Out:
#       mpg   car name  model year
# 322  46.6  mazda glc          80
